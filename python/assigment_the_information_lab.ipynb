# %% [markdown]
# ## Assigment -The information Lab
#
# --Assignement--
# Create and call a python function that :
# - stores a random integer A between 1 and 9
# - stores a random integer B between 1 and 9
# - multiplies A and B together as C

# %%
import random #I import random, a module that generates random intefrates. 

def generate_integers(): # I define the fuction here. Will call it generate integers.
    random_a = random.randint(1, 9) # first variable, random_a will return a random number from 1 to 9.
    random_b = random.randint(1, 9) #same as before, in this case the variable is called random_b.
    random_c = random_a * random_b #third part of the excersice, multiply 'a' and 'b' to get 'c'.

    print(f"Random integer A: {random_a}") #Once I run this code, it will be printed with the disered format.
    print(f"Random integer B: {random_b}")
    print(f"Random integer C,  result of Random_a * Random_b: {random_c}")
    return random_a, random_b, random_c # so we can see what numbers are they multiplying.

generate_integers(); #calling the function to see the outcome. ';' so I only get the 'print' part.
# Out:
# Random integer A: 7
# Random integer B: 8
# Random integer C,  result of Random_a * Random_b: 56

# %% [markdown]
# --Assignement--
# (Continuation of the previous part)
# - Prints A and C for every result until C = 4 (I don't understand why it says only to print A and C, but that's what it will print)
# - If C = 4 , print ‘Success!’ and the results for A and B

# %%
#I redefine the previous function. 

def generate_integers_till_4(): 
    while True: #instated of keeping the fuction as before I do a loop that will break when c== 4.
        random_a = random.randint(1, 9) 
        random_b = random.randint(1, 9) 
        random_c = random_a * random_b 

        print(f"Random integer A: {random_a}")
        print(f"Random integer B: {random_b}")
        print(f"Random integer C,  result of Random_a * Random_b: {random_c}")
        if random_c == 4:
            print ('Success!')
            break
#The fuction will print all the numbers until C == 4. 
generate_integers_till_4();
# Out:
# Random integer A: 8
# Random integer B: 1
# Random integer C,  result of Random_a * Random_b: 8
# Random integer A: 6
# Random integer B: 9
# Random integer C,  result of Random_a * Random_b: 54
# Random integer A: 7
# Random integer B: 5
# Random integer C,  result of Random_a * Random_b: 35
# Random integer A: 6
# Random integer B: 9
# Random integer C,  result of Random_a * Random_b: 54
# Random integer A: 7
# Random integer B: 6
# Random integer C,  result of Random_a * Random_b: 42
# Random integer A: 9
# Random integer B: 4
# Random integer C,  result of Random_a * Random_b: 36
# Random integer A: 5
# Random integer B: 2
# Random integer C,  result of Random_a * Random_b: 10
# Random integer A: 8
# Random integer B: 8
# Random integer C,  result of Random_a * Random_b: 64
# Random integer A: 5
# Random integer B: 7
# Random integer C,  result of Random_a * Random_b: 35
# Random integer A: 7
# Random integer B: 4
# Random integer C,  result of Random_a * Random_b: 28
# ...
